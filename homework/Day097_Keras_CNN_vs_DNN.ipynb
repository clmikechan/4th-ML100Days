# %%
import keras
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.optimizers import RMSprop, Adam
import os
# Out:
# Using TensorFlow backend.

# %%
batch_size = 128 # batch 的大小，如果出現 OOM error，請降低這個值
num_classes = 10 # 類別的數量，Cifar 10 共有 10 個類別
epochs = 10 # 訓練的 epochs 數量

# 讀取資料並檢視
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# 對 label 進行 one-hot encoding (y_trian 原本是純數字)
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %% [markdown]
# ## 首先我們使用一般的 DNN (MLP) 來訓練
# 由於 DNN 只能輸入一維的資料，我們要先將影像進行攤平，若 (50000, 32, 32, 3) 的影像，攤平後會變成 (50000, 32*32*3) = (50000, 3072)

# %%
# 將資料攤平成一維資料
x_train = x_train.reshape(50000, 3072) 
x_test = x_test.reshape(10000, 3072)

# 將資料變為 float32 並標準化
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# 50000 train samples
# 10000 test samples

# %%
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(3072,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))

model.summary()

model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 512)               1573376
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 1,841,162
# Trainable params: 1,841,162
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 6s 127us/step - loss: 2.1418 - accuracy: 0.2453 - val_loss: 1.8591 - val_accuracy: 0.3190
# Epoch 2/10
# 50000/50000 [==============================] - 4s 89us/step - loss: 1.8530 - accuracy: 0.3281 - val_loss: 1.7563 - val_accuracy: 0.3608
# Epoch 3/10
# 50000/50000 [==============================] - 4s 90us/step - loss: 1.7749 - accuracy: 0.3654 - val_loss: 1.7563 - val_accuracy: 0.3670
# Epoch 4/10
# 50000/50000 [==============================] - 5s 91us/step - loss: 1.7302 - accuracy: 0.3804 - val_loss: 1.7710 - val_accuracy: 0.3661
# Epoch 5/10
# 50000/50000 [==============================] - 5s 95us/step - loss: 1.6902 - accuracy: 0.3934 - val_loss: 1.6157 - val_accuracy: 0.4286
# Epoch 6/10
# 50000/50000 [==============================] - 5s 97us/step - loss: 1.6650 - accuracy: 0.4026 - val_loss: 1.6506 - val_accuracy: 0.3962
# Epoch 7/10
# 50000/50000 [==============================] - 5s 94us/step - loss: 1.6431 - accuracy: 0.4135 - val_loss: 1.6506 - val_accuracy: 0.4068
# Epoch 8/10
# 50000/50000 [==============================] - 5s 98us/step - loss: 1.6281 - accuracy: 0.4172 - val_loss: 1.6216 - val_accuracy: 0.4188
# Epoch 9/10
# 50000/50000 [==============================] - 5s 97us/step - loss: 1.6126 - accuracy: 0.4241 - val_loss: 1.6180 - val_accuracy: 0.4305
# Epoch 10/10
# 50000/50000 [==============================] - 5s 102us/step - loss: 1.5941 - accuracy: 0.4306 - val_loss: 1.5662 - val_accuracy: 0.4668
# Test loss: 1.5662186256408692
# Test accuracy: 0.4668000042438507

# %% [markdown]
# ## 接下來我們使用 CNN 來訓練神經網路
# CNN 的原理非常適合處理影像類的資料，就讓我們來看看，同樣的訓練條件，CNN 是否顯著優於 DNN 呢?

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), padding='same',
                 input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))
model.summary()

model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 30, 30, 32)        9248
# _________________________________________________________________
# activation_2 (Activation)    (None, 30, 30, 32)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 15, 15, 64)        18496
# _________________________________________________________________
# activation_3 (Activation)    (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 13, 13, 64)        36928
# _________________________________________________________________
# activation_4 (Activation)    (None, 13, 13, 64)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               1180160
# _________________________________________________________________
# activation_5 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                5130
# _________________________________________________________________
# activation_6 (Activation)    (None, 10)                0
# =================================================================
# Total params: 1,250,858
# Trainable params: 1,250,858
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 25s 507us/step - loss: 1.7511 - accuracy: 0.3669 - val_loss: 1.4219 - val_accuracy: 0.4752
# Epoch 2/10
# 50000/50000 [==============================] - 21s 430us/step - loss: 1.3325 - accuracy: 0.5282 - val_loss: 1.1485 - val_accuracy: 0.5944
# Epoch 3/10
# 50000/50000 [==============================] - 24s 474us/step - loss: 1.1142 - accuracy: 0.6065 - val_loss: 1.1023 - val_accuracy: 0.6173
# Epoch 4/10
# 50000/50000 [==============================] - 30s 603us/step - loss: 0.9800 - accuracy: 0.6560 - val_loss: 0.9515 - val_accuracy: 0.6687
# Epoch 5/10
# 50000/50000 [==============================] - 32s 635us/step - loss: 0.8894 - accuracy: 0.6910 - val_loss: 0.8217 - val_accuracy: 0.7115
# Epoch 6/10
# 50000/50000 [==============================] - 35s 704us/step - loss: 0.8175 - accuracy: 0.7165 - val_loss: 0.7294 - val_accuracy: 0.7493
# Epoch 7/10
# 50000/50000 [==============================] - 45s 908us/step - loss: 0.7604 - accuracy: 0.7376 - val_loss: 0.7314 - val_accuracy: 0.7457
# Epoch 8/10
# 50000/50000 [==============================] - 51s 1ms/step - loss: 0.7206 - accuracy: 0.7492 - val_loss: 0.7385 - val_accuracy: 0.7468
# Epoch 9/10
# 50000/50000 [==============================] - 54s 1ms/step - loss: 0.6885 - accuracy: 0.7634 - val_loss: 0.7066 - val_accuracy: 0.7652
# Epoch 10/10
# 50000/50000 [==============================] - 71s 1ms/step - loss: 0.6670 - accuracy: 0.7705 - val_loss: 0.8209 - val_accuracy: 0.7265
# Test loss: 0.8208505470275879
# Test accuracy: 0.7264999747276306

# %%
for batch_size in [64, 128, 256]:
    for optimizer in ["RMSprop", "Adam"]:
        model = Sequential()
        model.add(Conv2D(32, (3, 3), padding='same',
                         input_shape=x_train.shape[1:]))
        model.add(Activation('relu'))
        model.add(Conv2D(32, (3, 3)))
        model.add(Activation('relu'))
        model.add(MaxPooling2D(pool_size=(2, 2)))
        model.add(Dropout(0.25))

        model.add(Conv2D(64, (3, 3), padding='same'))
        model.add(Activation('relu'))
        model.add(Conv2D(64, (3, 3)))
        model.add(Activation('relu'))
        model.add(MaxPooling2D(pool_size=(2, 2)))
        model.add(Dropout(0.25))

        model.add(Flatten())
        model.add(Dense(512))
        model.add(Activation('relu'))
        model.add(Dropout(0.5))
        model.add(Dense(num_classes))
        model.add(Activation('softmax'))
        model.summary()
        print(f"batch size = {batch_size}, optimizer = {optimizer}")
        opt = Adam()
        if optimizer == "RMSprop":
            opt = RMSprop()
        model.compile(loss='categorical_crossentropy',
                      optimizer=opt,
                      metrics=['accuracy'])

        history = model.fit(x_train, y_train,
                            batch_size=batch_size,
                            epochs=epochs,
                            verbose=1,
                            validation_data=(x_test, y_test))
        score = model.evaluate(x_test, y_test, verbose=0)
        print('Test loss:', score[0])
        print('Test accuracy:', score[1])
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_5 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# activation_7 (Activation)    (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 30, 30, 32)        9248
# _________________________________________________________________
# activation_8 (Activation)    (None, 30, 30, 32)        0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 15, 15, 64)        18496
# _________________________________________________________________
# activation_9 (Activation)    (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 13, 13, 64)        36928
# _________________________________________________________________
# activation_10 (Activation)   (None, 13, 13, 64)        0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 512)               1180160
# _________________________________________________________________
# activation_11 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 10)                5130
# _________________________________________________________________
# activation_12 (Activation)   (None, 10)                0
# =================================================================
# Total params: 1,250,858
# Trainable params: 1,250,858
# Non-trainable params: 0
# _________________________________________________________________
# batch size = 64, optimizer = RMSprop
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 73s 1ms/step - loss: 1.6232 - accuracy: 0.4167 - val_loss: 1.3106 - val_accuracy: 0.5295
# Epoch 2/10
# 50000/50000 [==============================] - 99s 2ms/step - loss: 1.1871 - accuracy: 0.5813 - val_loss: 1.0276 - val_accuracy: 0.6388
# Epoch 3/10
# 50000/50000 [==============================] - 98s 2ms/step - loss: 1.0078 - accuracy: 0.6477 - val_loss: 1.0257 - val_accuracy: 0.6367
# Epoch 4/10
# 50000/50000 [==============================] - 92s 2ms/step - loss: 0.9035 - accuracy: 0.6869 - val_loss: 0.8932 - val_accuracy: 0.6813
# Epoch 5/10
# 50000/50000 [==============================] - 79s 2ms/step - loss: 0.8384 - accuracy: 0.7102 - val_loss: 0.8614 - val_accuracy: 0.7003
# Epoch 6/10
# 50000/50000 [==============================] - 99s 2ms/step - loss: 0.8055 - accuracy: 0.7235 - val_loss: 0.9344 - val_accuracy: 0.6863
# Epoch 7/10
# 50000/50000 [==============================] - 98s 2ms/step - loss: 0.7729 - accuracy: 0.7342 - val_loss: 0.7776 - val_accuracy: 0.7311
# Epoch 8/10
# 50000/50000 [==============================] - 96s 2ms/step - loss: 0.7548 - accuracy: 0.7419 - val_loss: 0.9578 - val_accuracy: 0.6873
# Epoch 9/10
# 50000/50000 [==============================] - 99s 2ms/step - loss: 0.7512 - accuracy: 0.7457 - val_loss: 0.8427 - val_accuracy: 0.7229
# Epoch 10/10
# 50000/50000 [==============================] - 99s 2ms/step - loss: 0.7437 - accuracy: 0.7494 - val_loss: 0.8174 - val_accuracy: 0.7298
# Test loss: 0.8174418251037597
# Test accuracy: 0.7297999858856201
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_9 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# activation_13 (Activation)   (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 30, 30, 32)        9248
# _________________________________________________________________
# activation_14 (Activation)   (None, 30, 30, 32)        0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 15, 15, 64)        18496
# _________________________________________________________________
# activation_15 (Activation)   (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 13, 13, 64)        36928
# _________________________________________________________________
# activation_16 (Activation)   (None, 13, 13, 64)        0
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 512)               1180160
# _________________________________________________________________
# activation_17 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 10)                5130
# _________________________________________________________________
# activation_18 (Activation)   (None, 10)                0
# =================================================================
# Total params: 1,250,858
# Trainable params: 1,250,858
# Non-trainable params: 0
# _________________________________________________________________
# batch size = 64, optimizer = Adam
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 101s 2ms/step - loss: 1.5756 - accuracy: 0.4252 - val_loss: 1.2259 - val_accuracy: 0.5608
# Epoch 2/10
# 50000/50000 [==============================] - 101s 2ms/step - loss: 1.1818 - accuracy: 0.5803 - val_loss: 1.0298 - val_accuracy: 0.6408
# Epoch 3/10
# 50000/50000 [==============================] - 98s 2ms/step - loss: 1.0186 - accuracy: 0.6404 - val_loss: 0.8796 - val_accuracy: 0.6934
# Epoch 4/10
# 50000/50000 [==============================] - 101s 2ms/step - loss: 0.9035 - accuracy: 0.6820 - val_loss: 0.8499 - val_accuracy: 0.7015
# Epoch 5/10
# 50000/50000 [==============================] - 101s 2ms/step - loss: 0.8248 - accuracy: 0.7115 - val_loss: 0.7824 - val_accuracy: 0.7235
# Epoch 6/10
# 50000/50000 [==============================] - 101s 2ms/step - loss: 0.7687 - accuracy: 0.7289 - val_loss: 0.7155 - val_accuracy: 0.7540
# Epoch 7/10
# 50000/50000 [==============================] - 102s 2ms/step - loss: 0.7317 - accuracy: 0.7412 - val_loss: 0.7262 - val_accuracy: 0.7473
# Epoch 8/10
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.6877 - accuracy: 0.7577 - val_loss: 0.6869 - val_accuracy: 0.7699
# Epoch 9/10
# 50000/50000 [==============================] - 101s 2ms/step - loss: 0.6547 - accuracy: 0.7672 - val_loss: 0.6603 - val_accuracy: 0.7717
# Epoch 10/10
# 50000/50000 [==============================] - 101s 2ms/step - loss: 0.6240 - accuracy: 0.7792 - val_loss: 0.7058 - val_accuracy: 0.7647
# Test loss: 0.7057865789413452
# Test accuracy: 0.7646999955177307
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_13 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# activation_19 (Activation)   (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 30, 30, 32)        9248
# _________________________________________________________________
# activation_20 (Activation)   (None, 30, 30, 32)        0
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 15, 15, 64)        18496
# _________________________________________________________________
# activation_21 (Activation)   (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 13, 13, 64)        36928
# _________________________________________________________________
# activation_22 (Activation)   (None, 13, 13, 64)        0
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_10 (Dense)             (None, 512)               1180160
# _________________________________________________________________
# activation_23 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 10)                5130
# _________________________________________________________________
# activation_24 (Activation)   (None, 10)                0
# =================================================================
# Total params: 1,250,858
# Trainable params: 1,250,858
# Non-trainable params: 0
# _________________________________________________________________
# batch size = 128, optimizer = RMSprop
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 92s 2ms/step - loss: 1.7793 - accuracy: 0.3538 - val_loss: 1.4733 - val_accuracy: 0.4767
# Epoch 2/10
# 50000/50000 [==============================] - 92s 2ms/step - loss: 1.3313 - accuracy: 0.5265 - val_loss: 1.1860 - val_accuracy: 0.5846
# Epoch 3/10
# 50000/50000 [==============================] - 92s 2ms/step - loss: 1.1245 - accuracy: 0.6030 - val_loss: 0.9422 - val_accuracy: 0.6694
# Epoch 4/10
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.9844 - accuracy: 0.6544 - val_loss: 1.0280 - val_accuracy: 0.6484
# Epoch 5/10
# 50000/50000 [==============================] - 92s 2ms/step - loss: 0.8927 - accuracy: 0.6878 - val_loss: 0.8069 - val_accuracy: 0.7182
# Epoch 6/10
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.8242 - accuracy: 0.7133 - val_loss: 0.8302 - val_accuracy: 0.7180
# Epoch 7/10
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.7717 - accuracy: 0.7308 - val_loss: 0.8316 - val_accuracy: 0.7180
# Epoch 8/10
# 50000/50000 [==============================] - 92s 2ms/step - loss: 0.7265 - accuracy: 0.7484 - val_loss: 0.7605 - val_accuracy: 0.7454
# Epoch 9/10
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.7012 - accuracy: 0.7563 - val_loss: 0.7537 - val_accuracy: 0.7458
# Epoch 10/10
# 50000/50000 [==============================] - 92s 2ms/step - loss: 0.6776 - accuracy: 0.7661 - val_loss: 0.7117 - val_accuracy: 0.7615
# Test loss: 0.7116529011726379
# Test accuracy: 0.7615000009536743
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_17 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# activation_25 (Activation)   (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 30, 30, 32)        9248
# _________________________________________________________________
# activation_26 (Activation)   (None, 30, 30, 32)        0
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 15, 15, 64)        18496
# _________________________________________________________________
# activation_27 (Activation)   (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 13, 13, 64)        36928
# _________________________________________________________________
# activation_28 (Activation)   (None, 13, 13, 64)        0
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 6, 6, 64)          0
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 512)               1180160
# _________________________________________________________________
# activation_29 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 10)                5130
# _________________________________________________________________
# activation_30 (Activation)   (None, 10)                0
# =================================================================
# Total params: 1,250,858
# Trainable params: 1,250,858
# Non-trainable params: 0
# _________________________________________________________________
# batch size = 128, optimizer = Adam
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 94s 2ms/step - loss: 1.6402 - accuracy: 0.3959 - val_loss: 1.2926 - val_accuracy: 0.5474
# Epoch 2/10
# 50000/50000 [==============================] - 94s 2ms/step - loss: 1.2236 - accuracy: 0.5618 - val_loss: 1.0195 - val_accuracy: 0.6368
# Epoch 3/10
# 50000/50000 [==============================] - 93s 2ms/step - loss: 1.0326 - accuracy: 0.6350 - val_loss: 0.9231 - val_accuracy: 0.6785
# Epoch 4/10
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.9208 - accuracy: 0.6748 - val_loss: 0.8180 - val_accuracy: 0.7205
# Epoch 5/10
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.8344 - accuracy: 0.7098 - val_loss: 0.7718 - val_accuracy: 0.7367
# Epoch 6/10
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.7758 - accuracy: 0.7270 - val_loss: 0.7573 - val_accuracy: 0.7401
# Epoch 7/10
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.7228 - accuracy: 0.7470 - val_loss: 0.7167 - val_accuracy: 0.7551
# Epoch 8/10
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.6876 - accuracy: 0.7601 - val_loss: 0.6818 - val_accuracy: 0.7671
# Epoch 9/10
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.6477 - accuracy: 0.7727 - val_loss: 0.6878 - val_accuracy: 0.7621
# Epoch 10/10
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.6175 - accuracy: 0.7822 - val_loss: 0.6583 - val_accuracy: 0.7747
# Test loss: 0.6583137657165528
# Test accuracy: 0.7746999859809875
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_21 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# activation_31 (Activation)   (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 30, 30, 32)        9248
# _________________________________________________________________
# activation_32 (Activation)   (None, 30, 30, 32)        0
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 15, 15, 64)        18496
# _________________________________________________________________
# activation_33 (Activation)   (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 13, 13, 64)        36928
# _________________________________________________________________
# activation_34 (Activation)   (None, 13, 13, 64)        0
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 6, 6, 64)          0
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_14 (Dense)             (None, 512)               1180160
# _________________________________________________________________
# activation_35 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_15 (Dense)             (None, 10)                5130
# _________________________________________________________________
# activation_36 (Activation)   (None, 10)                0
# =================================================================
# Total params: 1,250,858
# Trainable params: 1,250,858
# Non-trainable params: 0
# _________________________________________________________________
# batch size = 256, optimizer = RMSprop
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 90s 2ms/step - loss: 1.9040 - accuracy: 0.3136 - val_loss: 1.5870 - val_accuracy: 0.4172
# Epoch 2/10
# 50000/50000 [==============================] - 85s 2ms/step - loss: 1.5038 - accuracy: 0.4612 - val_loss: 1.3773 - val_accuracy: 0.5121
# Epoch 3/10
# 50000/50000 [==============================] - 79s 2ms/step - loss: 1.2853 - accuracy: 0.5465 - val_loss: 1.2043 - val_accuracy: 0.5803
# Epoch 4/10
# 50000/50000 [==============================] - 86s 2ms/step - loss: 1.1490 - accuracy: 0.5961 - val_loss: 1.0787 - val_accuracy: 0.6306
# Epoch 5/10
# 50000/50000 [==============================] - 72s 1ms/step - loss: 1.0296 - accuracy: 0.6400 - val_loss: 0.9960 - val_accuracy: 0.6451
# Epoch 6/10
# 50000/50000 [==============================] - 85s 2ms/step - loss: 0.9404 - accuracy: 0.6720 - val_loss: 1.0523 - val_accuracy: 0.6242
# Epoch 7/10
# 50000/50000 [==============================] - 85s 2ms/step - loss: 0.8730 - accuracy: 0.6948 - val_loss: 1.0562 - val_accuracy: 0.6394
# Epoch 8/10
# 50000/50000 [==============================] - 86s 2ms/step - loss: 0.8091 - accuracy: 0.7195 - val_loss: 0.9047 - val_accuracy: 0.6891
# Epoch 9/10
# 50000/50000 [==============================] - 86s 2ms/step - loss: 0.7623 - accuracy: 0.7348 - val_loss: 0.7937 - val_accuracy: 0.7203
# Epoch 10/10
# 50000/50000 [==============================] - 86s 2ms/step - loss: 0.7274 - accuracy: 0.7465 - val_loss: 0.8331 - val_accuracy: 0.7121
# Test loss: 0.8331058879852294
# Test accuracy: 0.7121000289916992
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_25 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# activation_37 (Activation)   (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 30, 30, 32)        9248
# _________________________________________________________________
# activation_38 (Activation)   (None, 30, 30, 32)        0
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 15, 15, 64)        18496
# _________________________________________________________________
# activation_39 (Activation)   (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 13, 13, 64)        36928
# _________________________________________________________________
# activation_40 (Activation)   (None, 13, 13, 64)        0
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 6, 6, 64)          0
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_16 (Dense)             (None, 512)               1180160
# _________________________________________________________________
# activation_41 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 10)                5130
# _________________________________________________________________
# activation_42 (Activation)   (None, 10)                0
# =================================================================
# Total params: 1,250,858
# Trainable params: 1,250,858
# Non-trainable params: 0
# _________________________________________________________________
# batch size = 256, optimizer = Adam
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 88s 2ms/step - loss: 1.7401 - accuracy: 0.3604 - val_loss: 1.4249 - val_accuracy: 0.4813
# Epoch 2/10
# 50000/50000 [==============================] - 87s 2ms/step - loss: 1.3622 - accuracy: 0.5086 - val_loss: 1.2693 - val_accuracy: 0.5492
# Epoch 3/10
# 50000/50000 [==============================] - 86s 2ms/step - loss: 1.1997 - accuracy: 0.5714 - val_loss: 1.0899 - val_accuracy: 0.6159
# Epoch 4/10
# 50000/50000 [==============================] - 86s 2ms/step - loss: 1.0746 - accuracy: 0.6191 - val_loss: 0.9715 - val_accuracy: 0.6564
# Epoch 5/10
# 50000/50000 [==============================] - 87s 2ms/step - loss: 0.9867 - accuracy: 0.6512 - val_loss: 0.8883 - val_accuracy: 0.6933
# Epoch 6/10
# 50000/50000 [==============================] - 86s 2ms/step - loss: 0.9182 - accuracy: 0.6761 - val_loss: 0.8818 - val_accuracy: 0.6969
# Epoch 7/10
# 50000/50000 [==============================] - 86s 2ms/step - loss: 0.8630 - accuracy: 0.6972 - val_loss: 0.8462 - val_accuracy: 0.7098
# Epoch 8/10
# 50000/50000 [==============================] - 69s 1ms/step - loss: 0.8136 - accuracy: 0.7141 - val_loss: 0.7591 - val_accuracy: 0.7344
# Epoch 9/10
# 50000/50000 [==============================] - 54s 1ms/step - loss: 0.7718 - accuracy: 0.7295 - val_loss: 0.7423 - val_accuracy: 0.7416
# Epoch 10/10
# 50000/50000 [==============================] - 56s 1ms/step - loss: 0.7429 - accuracy: 0.7397 - val_loss: 0.7232 - val_accuracy: 0.7491
# Test loss: 0.7232324940681457
# Test accuracy: 0.7491000294685364

# %% [markdown]
# ## 同樣運算 10 個 epochs，但 CNN 在 test data 的準確率顯著優於 DNN!

# %% [markdown]
# ## 作業
# 1. 請試著調整各個超參數，並說明那些超參數對於結果有明顯的影響?
# 2. CNN 與 DNN 哪個模型的參數數量比較多? 造成參數的數量不同的原因在哪?

# %% [markdown]
# # Ans:
# 1. batch_size 在 128 時的表現最好. optimizer Adam 的表現比 RMS 好
#
# 2. DNN 只有三層參數就比 CNN  六層還多. 另外可以看到 CNN 的參數大多集中在 Dense 部分. 可見主要差異在 Conv 層需要的參數遠小於 Dense 層.
